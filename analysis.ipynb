# %% [markdown]
# ### Better Life Index Regression Model - v1

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn
import sklearn.linear_model

# %%
# Pay attention to Encoding and Delimeters in source file
gpd_per_capita = pd.read_csv('data/gdp_per_capita.csv', encoding='latin1', delimiter='\t', thousands=',')
gpd_per_capita.head(50)
# Out:
#                              Country  \
# 0                        Afghanistan
# 1                            Albania
# 2                            Algeria
# 3                             Angola
# 4                Antigua and Barbuda
# 5                          Argentina
# 6                            Armenia
# 7                          Australia
# 8                            Austria
# 9                         Azerbaijan
# 10                       The Bahamas
# 11                           Bahrain
# 12                        Bangladesh
# 13                          Barbados
# 14                           Belarus
# 15                           Belgium
# 16                            Belize
# 17                             Benin
# 18                            Bhutan
# 19                           Bolivia
# 20            Bosnia and Herzegovina
# 21                          Botswana
# 22                            Brazil
# 23                 Brunei Darussalam
# ...

# %%
oecd_bli_2015 = pd.read_csv('data/oecd_bli_2015.csv')
oecd_bli_2015.head()

# %%
def join_imf_and_oecd(oecd, gdp):
    """
    This function merges the OECD's life satisfaction data and
    IMF's GDP per capita data
    """
